# %% [markdown]
# # Facebook Engagement Analysis - Exploratory Data Analysis
#
# Author: Nick Peril
# Project: TKH Phase I Portfolio
# Dataset: Facebook Metrics (UCI Repository)
#
# ## Objective
# To explore the dataset and identify patterns that influence post engagement.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading my dataset:

# %%
df = pd.read_csv("/Users/saadult/facebook-engagement-analysis/data/raw/dataset_Facebook.csv")

# %% [markdown]
# Displaying the first 20 rows:

# %%
df. head(20)
# Out:
#    Page total likes;Type;Category;Post Month;Post Weekday;Post Hour;Paid;Lifetime Post Total Reach;Lifetime Post Total Impressions;Lifetime Engaged Users;Lifetime Post Consumers;Lifetime Post Consumptions;Lifetime Post Impressions by people who have liked your Page;Lifetime Post reach by people who like your Page;Lifetime People who have liked your Page and engaged with your post;comment;like;share;Total Interactions
# 0   139441;Photo;2;12;4;3;0;2752;5091;178;109;159;...
# 1   139441;Status;2;12;3;10;0;10460;19057;1457;136...
# 2   139441;Photo;3;12;3;3;0;2413;4373;177;113;154;...
# 3   139441;Photo;2;12;2;10;1;50128;87991;2211;790;...
# 4   139441;Photo;2;12;2;3;0;7244;13594;671;410;580...
# 5   139441;Status;2;12;1;9;0;10472;20849;1191;1073...
# 6   139441;Photo;3;12;1;3;1;11692;19479;481;265;36...
# 7   139441;Photo;3;12;7;9;1;13720;24137;537;232;30...
# 8   139441;Status;2;12;7;3;0;11844;22538;1530;1407...
# 9   139441;Photo;3;12;6;10;0;4694;8668;280;183;250...
# ...

# %%
df.shape
# Out:
# (500, 1)

# %% [markdown]
# The dataset contains 500 rows and only 1 column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                                             Non-Null Count  Dtype
# ...

# %%
df.describe()
# Out:
#        Page total likes;Type;Category;Post Month;Post Weekday;Post Hour;Paid;Lifetime Post Total Reach;Lifetime Post Total Impressions;Lifetime Engaged Users;Lifetime Post Consumers;Lifetime Post Consumptions;Lifetime Post Impressions by people who have liked your Page;Lifetime Post reach by people who like your Page;Lifetime People who have liked your Page and engaged with your post;comment;like;share;Total Interactions
# count                                                 500
# unique                                                500
# top     139441;Photo;2;12;4;3;0;2752;5091;178;109;159;...
# freq                                                    1
